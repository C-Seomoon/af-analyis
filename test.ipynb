# %%
import af_analysis

# %matplotlib inline

# %%
DATA_PATH="/home/cseomoon/project/TMEM120A/inference_data/tmem120a-coa_mouse"
my_data = af_analysis.Data(DATA_PATH, format="AF3")

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

# %%
my_data.df
# Out:
#                                                                                              pdb  \
# 0    /home/cseomoon/project/TMEM120A/inference_data/tmem120a-coa_mouse/seed-1_sample-0/model.cif
# 1    /home/cseomoon/project/TMEM120A/inference_data/tmem120a-coa_mouse/seed-1_sample-1/model.cif
# 2    /home/cseomoon/project/TMEM120A/inference_data/tmem120a-coa_mouse/seed-1_sample-2/model.cif
# 3    /home/cseomoon/project/TMEM120A/inference_data/tmem120a-coa_mouse/seed-1_sample-3/model.cif
# 4    /home/cseomoon/project/TMEM120A/inference_data/tmem120a-coa_mouse/seed-1_sample-4/model.cif
# 5    /home/cseomoon/project/TMEM120A/inference_data/tmem120a-coa_mouse/seed-2_sample-0/model.cif
# 6    /home/cseomoon/project/TMEM120A/inference_data/tmem120a-coa_mouse/seed-2_sample-1/model.cif
# 7    /home/cseomoon/project/TMEM120A/inference_data/tmem120a-coa_mouse/seed-2_sample-2/model.cif
# 8    /home/cseomoon/project/TMEM120A/inference_data/tmem120a-coa_mouse/seed-2_sample-3/model.cif
# ...

# %%
my_data.chain_length
my_data.chains
# Out:
# {'tmem120a-coa_mouse': ['A', 'B', 'D', 'E']}

# %%
best_ipTM_index = my_data.df['ipTM'].idxmax()
worst_ipTM_index = my_data.df['ipTM'].idxmin()

# %%
my_data.df.iloc[best_ipTM_index]
# Out:
# pdb                                 /home/cseomoon/project/TMEM120A/inference_data/tmem120a-coa_mouse/seed-1_sample-0/model.cif
# query                                                                                                        tmem120a-coa_mouse
# seed                                                                                                                          1
# sample                                                                                                                        0
# data_file                    /home/cseomoon/project/TMEM120A/inference_data/tmem120a-coa_mouse/seed-1_sample-0/confidences.json
# chain_iptm                                                                                             [0.86, 0.86, 0.68, 0.68]
# chain_pair_iptm        [[0.83, 0.85, 0.93, 0.82], [0.85, 0.83, 0.82, 0.93], [0.93, 0.82, 0.65, 0.28], [0.82, 0.93, 0.28, 0.65]]
# ...

# %%
my_data.plot_plddt([best_ipTM_index])
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: xlabel='Residue', ylabel='predicted LDDT'>)

# %%
my_data.plot_plddt([best_ipTM_index, worst_ipTM_index])
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: xlabel='Residue', ylabel='predicted LDDT'>)

# %%
my_data.plot_pae(best_ipTM_index)
# Out:
# (<Figure size 640x480 with 2 Axes>, <Axes: >)

# %%
view = my_data.show_3d(best_ipTM_index)
view
# Out:
# NGLWidget()

# %%
from IPython.display import IFrame
IFrame(src='../_static/dimer.html', width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="../_static/dimer.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from af_analysis import analysis

#compute_pdockq
analysis.pdockq(my_data)
#compute_pdockq2
analysis.pdockq2(my_data)
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[27], line 6
#       4 analysis.pdockq(my_data)
#       5 #compute_pdockq2
# ----> 6 analysis.pdockq2(my_data)
#
# File ~/appl/af_analysis-0.1.4/src/af_analysis/analysis.py:293, in pdockq2(data, verbose)
#     288 # with open(json_path) as f:
#     289 #     local_json = json.load(f)
#     290 # pae_array = np.array(local_json["pae"])
#     291 pae_array = get_pae(data_path)
# --> 293 pdockq2 = compute_pdockQ2(model, pae_array)
#     295 for i in range(max_chain_num):
#     296     if i < len(pdockq2):
#
# File ~/miniconda3/envs/Abnb/lib/python3.10/site-packages/pdb_numpy/analysis.py:783, in compute_pdockQ2(coor, pae_array, cutoff, L, x0, k, b, d0, sel)
#     780 models_CA = coor.select_atoms(sel)
#     781 models_chains = np.unique(models_CA.chain)
# ...

# %%
print(f"PAE shape: {pae_array.shape}, CA atoms: {models_CA.len}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 print(f"PAE shape: {pae_array.shape}, CA atoms: {models_CA.len}")
#
# NameError: name 'pae_array' is not defined

# %%
my_data.chains['tmem120a-coa_mouse']
# Out:
# ['A', 'B', 'D', 'E']

# %%
from tqdm import tqdm
from af_analysis import analysis
import pdb_numpy

from pdb_numpy.analysis import compute_pdockQ2

for pdb, data_path in tqdm(zip(my_data.df["pdb"], my_data.df["data_file"])):
    model = pdb_numpy.Coor(pdb)
    print(model)
    pae_array = analysis.get_pae(data_path)
    
    #pdockq2 = compute_pdockQ2(model, pae_array)
    print(pae_array.shape)
    break
# Out:
# 0it [00:00, ?it/s]
# ...
# 0it [00:00, ?it/s]
# (782, 782)

# %%
# 객체의 내부 속성 확인
import pprint
pprint.pprint(vars(model))

# 모델의 첫 번째 원자 몇 개 정보 출력
print("\n첫 번째 모델의 원자 정보 (처음 5개):")
for i in range(min(5, model.models[0].len)):
    print(f"원자 {i+1}: {model.models[0].name[i]} - 체인 {model.models[0].chain[i]} - 잔기 {model.models[0].resid[i]} ({model.models[0].resname[i]})")
# Out:
# {'active_model': 0,
#  'crystal_pack': '',
#  'data_mmCIF': OrderedDict([('title',
#                              OrderedDict([('title',
#                                            'data_tmem120a-coa_mouse')])),
#                             ('_entry',
#                              OrderedDict([('id', 'tmem120a-coa_mouse')])),
#                             ('_atom_type',
#                              {'col_names': ['symbol'],
#                               'value': [['C', 'N', 'O', 'P', 'S']]}),
#                             ('_audit_author',
#                              {'col_names': ['name', 'pdbx_ordinal'],
#                               'value': [['"Google DeepMind"',
#                                          '"Isomorphic Labs"'],
#                                         ['1', '2']]}),
#                             ('_audit_conform',
#                              OrderedDict([('dict_location',
# ...

# %%
import numpy as np

# 기본 정보 확인
print("객체 타입:", type(model))
print("모델 수:", len(model.models))

# 첫 번째 모델 정보 출력
print("\n첫 번째 모델 정보:")
print("원자 수:", model.models[0].len)
print("체인 목록:", list(np.unique(model.models[0].chain)))
print("아미노산 수:", len(np.unique(model.models[0].uniq_resid)))

# 체인별 잔기 수 확인
print("\n체인별 잔기 수:")
for chain in np.unique(model.models[0].chain):
    chain_resids = model.models[0].uniq_resid[model.models[0].chain == chain]
    print(f"체인 {chain}: {len(np.unique(chain_resids))} 잔기")

# CA 원자 정보
ca_atoms = model.select_atoms("name CA")
print("\nCA 원자 정보:")
print("CA 원자 수:", ca_atoms.len)

# 추가 정보 확인을 위한 메서드
print("\n사용 가능한 메서드:")
print([method for method in dir(model) if not method.startswith('_')][:10])  # 처음 10개만
# Out:
# 객체 타입: <class 'pdb_numpy.coor.Coor'>
# 모델 수: 1
#
# 첫 번째 모델 정보:
# 원자 수: 5854
# 체인 목록: ['A', 'B', 'D', 'E']
# 아미노산 수: 687
#
# 체인별 잔기 수:
# 체인 A: 343 잔기
# 체인 B: 343 잔기
# 체인 D: 1 잔기
# 체인 E: 1 잔기
#
# CA 원자 정보:
# CA 원자 수: 686
#
# 사용 가능한 메서드:
# ['active_model', 'add_symmetry', 'alterloc', 'apply_transformation', 'beta', 'chain', 'change_order', 'com', 'compute_chains_CA', 'copy_box']
