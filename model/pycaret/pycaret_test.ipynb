# %%
pd.set_option('display.max_columns', None)

# %%
# calc_classification.py
import matplotlib as mpl
mpl.rcParams['font.family'] = 'DejaVu Sans'
# 필요하다면 sans-serif 계열을 강제 지정
mpl.rcParams['font.sans-serif'] = ['DejaVu Sans']
import sys
# classification 패키지가 있는 상위 폴더를 직접 지정
sys.path.insert(0, "/home/cseomoon/appl/af_analysis-0.1.4/model")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from pycaret.classification import *
from sklearn.metrics import (
    roc_auc_score, accuracy_score, f1_score,
    confusion_matrix, classification_report,
    precision_recall_curve, average_precision_score,
    roc_curve
)

from classification.utils.data_loader import load_and_preprocess_data

# %%
# 1) 경로 정의
train_fp = "/home/cseomoon/appl/af_analysis-0.1.4/model/classification/data/train/pipeline_AbNb_native_data.csv"
test_fp  = "/home/cseomoon/appl/af_analysis-0.1.4/model/classification/data/test/pipeline_ABAG_native_data.csv"

# 2) 데이터 로드 및 전처리
X_train, y_train, groups = load_and_preprocess_data(
    train_fp,
    target_column="DockQ",
    threshold=0.23,
    query_id_column="query"
)
X_test, y_test, _ = load_and_preprocess_data(
    test_fp,
    target_column="DockQ",
    threshold=0.23,
    query_id_column="query"
)

# 3) DataFrame 생성
train_df = X_train.copy()
train_df["target"] = y_train.values
test_df = X_test.copy()
test_df["target"] = y_test.values

# 4) PyCaret 설정 (5-Fold 그룹KFold, GPU 사용, 정규화)
clf_setup = setup(
    data=train_df,
    target="target",
    session_id=42,
    fold_strategy="groupkfold",
    fold=5,
    fold_groups=groups,
    normalize=True,
    use_gpu=False,
    verbose=True,
    log_experiment=False
)
# Out:
# Original data shape: (3650, 90)
# Class distribution before NaN drop (DockQ >= 0.23): 0 (Negative) = 2529, 1 (Positive) = 1121
# Found 'LIS' column in the data. It will be dropped from features.
# Identified 71 potential feature columns.
# Checking for NaN values in potential feature columns...
# Dropped 3 rows containing NaN values in one or more feature columns.
# Processed Features (X) shape after NaN drop: (3647, 71)
# Processed Target (y) shape after NaN drop: (3647,)
# Processed Query IDs shape after NaN drop: (3647,)
# Class distribution after NaN drop (DockQ >= 0.23): 0 (Negative) = 2526, 1 (Positive) = 1121
# Original data shape: (1650, 90)
# Class distribution before NaN drop (DockQ >= 0.23): 0 (Negative) = 1022, 1 (Positive) = 628
# Found 'LIS' column in the data. It will be dropped from features.
# Identified 71 potential feature columns.
# Checking for NaN values in potential feature columns...
# Dropped 2 rows containing NaN values in one or more feature columns.
# Processed Features (X) shape after NaN drop: (1648, 71)
# Processed Target (y) shape after NaN drop: (1648,)
# Processed Query IDs shape after NaN drop: (1648,)
# Class distribution after NaN drop (DockQ >= 0.23): 0 (Negative) = 1020, 1 (Positive) = 628
# <style type="text/css">
# #T_ba5a6_row8_col1, #T_ba5a6_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ba5a6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba5a6_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ba5a6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba5a6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ba5a6_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ba5a6_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_ba5a6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ba5a6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ba5a6_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_ba5a6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ba5a6_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_ba5a6_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_ba5a6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ba5a6_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_ba5a6_row3_col1" class="data row3 col1" >(3647, 72)</td>
#     </tr>
#     <tr>
#       <th id="T_ba5a6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ba5a6_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_ba5a6_row4_col1" class="data row4 col1" >(3647, 72)</td>
#     </tr>
#     <tr>
#       <th id="T_ba5a6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ba5a6_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_ba5a6_row5_col1" class="data row5 col1" >(2552, 72)</td>
#     </tr>
#     <tr>
#       <th id="T_ba5a6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ba5a6_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_ba5a6_row6_col1" class="data row6 col1" >(1095, 72)</td>
#     </tr>
#     <tr>
#       <th id="T_ba5a6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ba5a6_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_ba5a6_row7_col1" class="data row7 col1" >71</td>
#     </tr>
#     <tr>
#       <th id="T_ba5a6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ba5a6_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_ba5a6_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ba5a6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ba5a6_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_ba5a6_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_ba5a6_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ba5a6_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_ba5a6_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_ba5a6_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ba5a6_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_ba5a6_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_ba5a6_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ba5a6_row12_col0" class="data row12 col0" >Normalize</td>
#       <td id="T_ba5a6_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ba5a6_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ba5a6_row13_col0" class="data row13 col0" >Normalize method</td>
#       <td id="T_ba5a6_row13_col1" class="data row13 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_ba5a6_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ba5a6_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_ba5a6_row14_col1" class="data row14 col1" >GroupKFold</td>
#     </tr>
#     <tr>
#       <th id="T_ba5a6_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ba5a6_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_ba5a6_row15_col1" class="data row15 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_ba5a6_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ba5a6_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_ba5a6_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_ba5a6_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ba5a6_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_ba5a6_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ba5a6_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_ba5a6_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_ba5a6_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ba5a6_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_ba5a6_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_ba5a6_row19_col1" class="data row19 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_ba5a6_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_ba5a6_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_ba5a6_row20_col1" class="data row20 col1" >d3fd</td>
#     </tr>
#   </tbody>
# </table>

# %%
# add metric to PyCaret
add_metric('pr_ap', 'PR-AP', average_precision_score)
# Out:
# Name                                                             PR-AP
# Display Name                                                     PR-AP
# Score Function       <pycaret.internal.metrics.EncodedDecodedLabels...
# Scorer               make_scorer(average_precision_score, response_...
# Target                                                            pred
# Args                                                                {}
# Greater is Better                                                 True
# Multiclass                                                        True
# Custom                                                            True
# Name: pr_ap, dtype: object

# %%
# 5) 모델 비교 및 선택 (전체 모델 대상, 내부 CV 결과 확인)
top5 = compare_models(
    n_select=5,
    sort="AUC"
)
print("=== Top 5 모델 (내부 5-Fold CV) ===")
print(pull().head(5))
# Out:
# <style type="text/css">
# #T_e9400 th {
#   text-align: left;
# }
# #T_e9400_row0_col0, #T_e9400_row0_col1, #T_e9400_row0_col3, #T_e9400_row0_col4, #T_e9400_row0_col5, #T_e9400_row0_col6, #T_e9400_row0_col7, #T_e9400_row0_col8, #T_e9400_row1_col0, #T_e9400_row1_col1, #T_e9400_row1_col2, #T_e9400_row1_col3, #T_e9400_row1_col4, #T_e9400_row1_col5, #T_e9400_row1_col6, #T_e9400_row1_col7, #T_e9400_row1_col8, #T_e9400_row2_col0, #T_e9400_row2_col1, #T_e9400_row2_col2, #T_e9400_row2_col3, #T_e9400_row2_col4, #T_e9400_row2_col5, #T_e9400_row2_col6, #T_e9400_row2_col7, #T_e9400_row2_col8, #T_e9400_row3_col0, #T_e9400_row3_col1, #T_e9400_row3_col2, #T_e9400_row3_col3, #T_e9400_row3_col4, #T_e9400_row3_col5, #T_e9400_row3_col6, #T_e9400_row3_col7, #T_e9400_row3_col8, #T_e9400_row4_col0, #T_e9400_row4_col2, #T_e9400_row4_col3, #T_e9400_row5_col0, #T_e9400_row5_col1, #T_e9400_row5_col2, #T_e9400_row5_col3, #T_e9400_row5_col4, #T_e9400_row5_col5, #T_e9400_row5_col6, #T_e9400_row5_col7, #T_e9400_row5_col8, #T_e9400_row6_col0, #T_e9400_row6_col1, #T_e9400_row6_col2, #T_e9400_row6_col3, #T_e9400_row6_col4, #T_e9400_row6_col5, #T_e9400_row6_col6, #T_e9400_row6_col7, #T_e9400_row6_col8, #T_e9400_row7_col0, #T_e9400_row7_col1, #T_e9400_row7_col2, #T_e9400_row7_col3, #T_e9400_row7_col4, #T_e9400_row7_col5, #T_e9400_row7_col6, #T_e9400_row7_col7, #T_e9400_row7_col8, #T_e9400_row8_col0, #T_e9400_row8_col1, #T_e9400_row8_col2, #T_e9400_row8_col4, #T_e9400_row8_col5, #T_e9400_row8_col6, #T_e9400_row8_col7, #T_e9400_row8_col8, #T_e9400_row9_col0, #T_e9400_row9_col1, #T_e9400_row9_col2, #T_e9400_row9_col3, #T_e9400_row9_col4, #T_e9400_row9_col5, #T_e9400_row9_col6, #T_e9400_row9_col7, #T_e9400_row9_col8, #T_e9400_row10_col0, #T_e9400_row10_col1, #T_e9400_row10_col2, #T_e9400_row10_col3, #T_e9400_row10_col4, #T_e9400_row10_col5, #T_e9400_row10_col6, #T_e9400_row10_col7, #T_e9400_row10_col8, #T_e9400_row11_col0, #T_e9400_row11_col1, #T_e9400_row11_col2, #T_e9400_row11_col3, #T_e9400_row11_col4, #T_e9400_row11_col5, #T_e9400_row11_col6, #T_e9400_row11_col7, #T_e9400_row11_col8, #T_e9400_row12_col0, #T_e9400_row12_col1, #T_e9400_row12_col2, #T_e9400_row12_col3, #T_e9400_row12_col4, #T_e9400_row12_col5, #T_e9400_row12_col6, #T_e9400_row12_col7, #T_e9400_row12_col8, #T_e9400_row13_col0, #T_e9400_row13_col1, #T_e9400_row13_col2, #T_e9400_row13_col3, #T_e9400_row13_col4, #T_e9400_row13_col5, #T_e9400_row13_col6, #T_e9400_row13_col7, #T_e9400_row13_col8, #T_e9400_row14_col0, #T_e9400_row14_col1, #T_e9400_row14_col2, #T_e9400_row14_col3, #T_e9400_row14_col4, #T_e9400_row14_col5, #T_e9400_row14_col6, #T_e9400_row14_col7, #T_e9400_row14_col8, #T_e9400_row15_col0, #T_e9400_row15_col1, #T_e9400_row15_col2, #T_e9400_row15_col3, #T_e9400_row15_col4, #T_e9400_row15_col5, #T_e9400_row15_col6, #T_e9400_row15_col7, #T_e9400_row15_col8 {
#   text-align: left;
# }
# #T_e9400_row0_col2, #T_e9400_row4_col1, #T_e9400_row4_col4, #T_e9400_row4_col5, #T_e9400_row4_col6, #T_e9400_row4_col7, #T_e9400_row4_col8, #T_e9400_row8_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_e9400_row0_col9, #T_e9400_row1_col9, #T_e9400_row2_col9, #T_e9400_row3_col9, #T_e9400_row4_col9, #T_e9400_row5_col9, #T_e9400_row6_col9, #T_e9400_row7_col9, #T_e9400_row8_col9, #T_e9400_row10_col9, #T_e9400_row11_col9, #T_e9400_row12_col9, #T_e9400_row13_col9, #T_e9400_row14_col9, #T_e9400_row15_col9 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_e9400_row9_col9 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_e9400">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9400_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e9400_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_e9400_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_e9400_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_e9400_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_e9400_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_e9400_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_e9400_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_e9400_level0_col8" class="col_heading level0 col8" >PR-AP</th>
#       <th id="T_e9400_level0_col9" class="col_heading level0 col9" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9400_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_e9400_row0_col0" class="data row0 col0" >CatBoost Classifier</td>
#       <td id="T_e9400_row0_col1" class="data row0 col1" >0.8695</td>
#       <td id="T_e9400_row0_col2" class="data row0 col2" >0.9302</td>
#       <td id="T_e9400_row0_col3" class="data row0 col3" >0.7248</td>
#       <td id="T_e9400_row0_col4" class="data row0 col4" >0.7875</td>
#       <td id="T_e9400_row0_col5" class="data row0 col5" >0.7528</td>
#       <td id="T_e9400_row0_col6" class="data row0 col6" >0.6542</td>
#       <td id="T_e9400_row0_col7" class="data row0 col7" >0.6570</td>
#       <td id="T_e9400_row0_col8" class="data row0 col8" >0.6632</td>
#       <td id="T_e9400_row0_col9" class="data row0 col9" >4.6480</td>
#     </tr>
#     <tr>
#       <th id="T_e9400_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_e9400_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_e9400_row1_col1" class="data row1 col1" >0.8723</td>
#       <td id="T_e9400_row1_col2" class="data row1 col2" >0.9295</td>
#       <td id="T_e9400_row1_col3" class="data row1 col3" >0.7186</td>
#       <td id="T_e9400_row1_col4" class="data row1 col4" >0.7906</td>
#       <td id="T_e9400_row1_col5" class="data row1 col5" >0.7502</td>
#       <td id="T_e9400_row1_col6" class="data row1 col6" >0.6550</td>
#       <td id="T_e9400_row1_col7" class="data row1 col7" >0.6585</td>
#       <td id="T_e9400_row1_col8" class="data row1 col8" >0.6634</td>
#       <td id="T_e9400_row1_col9" class="data row1 col9" >0.9920</td>
#     </tr>
#     <tr>
#       <th id="T_e9400_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_e9400_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_e9400_row2_col1" class="data row2 col1" >0.8632</td>
#       <td id="T_e9400_row2_col2" class="data row2 col2" >0.9269</td>
#       <td id="T_e9400_row2_col3" class="data row2 col3" >0.7306</td>
#       <td id="T_e9400_row2_col4" class="data row2 col4" >0.7631</td>
#       <td id="T_e9400_row2_col5" class="data row2 col5" >0.7426</td>
#       <td id="T_e9400_row2_col6" class="data row2 col6" >0.6385</td>
#       <td id="T_e9400_row2_col7" class="data row2 col7" >0.6420</td>
#       <td id="T_e9400_row2_col8" class="data row2 col8" >0.6458</td>
#       <td id="T_e9400_row2_col9" class="data row2 col9" >0.9280</td>
#     </tr>
#     <tr>
#       <th id="T_e9400_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_e9400_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_e9400_row3_col1" class="data row3 col1" >0.8772</td>
#       <td id="T_e9400_row3_col2" class="data row3 col2" >0.9227</td>
#       <td id="T_e9400_row3_col3" class="data row3 col3" >0.7896</td>
#       <td id="T_e9400_row3_col4" class="data row3 col4" >0.7570</td>
#       <td id="T_e9400_row3_col5" class="data row3 col5" >0.7703</td>
#       <td id="T_e9400_row3_col6" class="data row3 col6" >0.6776</td>
#       <td id="T_e9400_row3_col7" class="data row3 col7" >0.6795</td>
#       <td id="T_e9400_row3_col8" class="data row3 col8" >0.6722</td>
#       <td id="T_e9400_row3_col9" class="data row3 col9" >7.3060</td>
#     </tr>
#     <tr>
#       <th id="T_e9400_level0_row4" class="row_heading level0 row4" >nb</th>
#       <td id="T_e9400_row4_col0" class="data row4 col0" >Naive Bayes</td>
#       <td id="T_e9400_row4_col1" class="data row4 col1" >0.8979</td>
#       <td id="T_e9400_row4_col2" class="data row4 col2" >0.9221</td>
#       <td id="T_e9400_row4_col3" class="data row4 col
# === Top 5 모델 (내부 5-Fold CV) ===
#                              Model  Accuracy     AUC  Recall   Prec.      F1  \
# catboost       CatBoost Classifier    0.8695  0.9302  0.7248  0.7875  0.7528
# et          Extra Trees Classifier    0.8723  0.9295  0.7186  0.7906  0.7502
# rf        Random Forest Classifier    0.8632  0.9269  0.7306  0.7631  0.7426
# lr             Logistic Regression    0.8772  0.9227  0.7896  0.7570  0.7703
# nb                     Naive Bayes    0.8979  0.9221  0.7543  0.8458  0.7962
#
#            Kappa     MCC   PR-AP  TT (Sec)
# catboost  0.6542  0.6570  0.6632     4.648
# et        0.6550  0.6585  0.6634     0.992
# rf        0.6385  0.6420  0.6458     0.928
# lr        0.6776  0.6795  0.6722     7.306
# nb        0.7200  0.7234  0.7148     0.460

# %%
new_data=test_df.copy()
new_data.drop('target', axis=1, inplace=True)
new_data.head()
# Out:
#    fraction_disordered  has_clash  ipTM   pTM  ranking_confidence  iptm_A  \
# 0                 0.00        0.0  0.57  0.70                0.60    0.11
# 1                 0.01        0.0  0.57  0.70                0.61    0.12
# 2                 0.00        0.0  0.55  0.69                0.58    0.07
# 3                 0.00        0.0  0.57  0.70                0.60    0.12
# 4                 0.01        0.0  0.57  0.70                0.60    0.11
#
#    iptm_H  iptm_L  ptm_A  ptm_H  ...  query_avg_RMSD  scaled_RMSD_ratio  \
# 0    0.50    0.50   0.72   0.88  ...       39.246214           0.559606
# 1    0.50    0.50   0.73   0.88  ...       39.246214           0.579124
# 2    0.48    0.48   0.74   0.89  ...       39.246214           0.401814
# 3    0.50    0.50   0.73   0.87  ...       39.246214           0.609161
# 4    0.50    0.50   0.75   0.89  ...       39.246214           0.419686
#
#    scaled_model_RMSD  scaled_query_RMSD  dG_separated    dSASA_int  nres_int  \
# 0           0.056252           0.044806     19.708321  1472.935064      47.0
# 1           0.060631           0.044806     59.586646  1843.671070      60.0
# 2           0.030546           0.044806     56.250134  1609.165063      53.0
# 3           0.068129           0.044806     27.314403  1546.077081      54.0
# 4           0.032811           0.044806     20.159038  1206.538153      43.0
#
#    delta_unsatHbonds  packstat  dG_dSASA_norm
# 0               17.0  0.713741       0.013380
# 1               21.0  0.674735       0.032320
# 2               11.0  0.741571       0.034956
# 3               21.0  0.729679       0.017667
# 4                6.0  0.749578       0.016708
#
# [5 rows x 71 columns]

# %%
# 6) 최상위 모델 최종화
best = top5[0]
final_model = finalize_model(best)

predictions = predict_model(final_model, data=new_data)
predictions.head()
# Out:
#    fraction_disordered  has_clash  ipTM   pTM  ranking_confidence  iptm_A  \
# 0                 0.00        0.0  0.57  0.70                0.60    0.11
# 1                 0.01        0.0  0.57  0.70                0.61    0.12
# 2                 0.00        0.0  0.55  0.69                0.58    0.07
# 3                 0.00        0.0  0.57  0.70                0.60    0.12
# 4                 0.01        0.0  0.57  0.70                0.60    0.11
#
#    iptm_H  iptm_L  ptm_A  ptm_H  ...  scaled_model_RMSD  scaled_query_RMSD  \
# 0    0.50    0.50   0.72   0.88  ...           0.056252           0.044806
# 1    0.50    0.50   0.73   0.88  ...           0.060631           0.044806
# 2    0.48    0.48   0.74   0.89  ...           0.030546           0.044806
# 3    0.50    0.50   0.73   0.87  ...           0.068129           0.044806
# 4    0.50    0.50   0.75   0.89  ...           0.032811           0.044806
#
#    dG_separated    dSASA_int  nres_int  delta_unsatHbonds  packstat  \
# 0     19.708321  1472.935059      47.0               17.0  0.713741
# 1     59.586647  1843.671021      60.0               21.0  0.674735
# 2     56.250134  1609.165039      53.0               11.0  0.741571
# 3     27.314404  1546.077026      54.0               21.0  0.729679
# 4     20.159039  1206.538208      43.0                6.0  0.749578
#
#    dG_dSASA_norm  prediction_label  prediction_score
# 0       0.013380                 0            0.9715
# 1       0.032320                 0            0.9835
# 2       0.034956                 0            0.9957
# 3       0.017667                 0            0.9827
# 4       0.016708                 0            0.9842
#
# [5 rows x 73 columns]

# %%
X_test
# Out:
#       fraction_disordered  has_clash  ipTM   pTM  ranking_confidence  iptm_A  \
# 0                    0.00        0.0  0.57  0.70                0.60    0.11
# 1                    0.01        0.0  0.57  0.70                0.61    0.12
# 2                    0.00        0.0  0.55  0.69                0.58    0.07
# 3                    0.00        0.0  0.57  0.70                0.60    0.12
# 4                    0.01        0.0  0.57  0.70                0.60    0.11
# ...                   ...        ...   ...   ...                 ...     ...
# 1645                 0.01        0.0  0.21  0.65                0.30    0.13
# 1646                 0.01        0.0  0.21  0.65                0.31    0.14
# 1647                 0.01        0.0  0.21  0.65                0.30    0.15
# 1648                 0.01        0.0  0.21  0.65                0.30    0.14
# 1649                 0.01        0.0  0.21  0.64                0.30    0.15
#
#       iptm_H  iptm_L  ptm_A  ptm_H  ...  query_avg_RMSD  scaled_RMSD_ratio  \
# 0       0.50    0.50   0.72   0.88  ...       39.246214           0.559606
# 1       0.50    0.50   0.73   0.88  ...       39.246214           0.579124
# 2       0.48    0.48   0.74   0.89  ...       39.246214           0.401814
# 3       0.50    0.50   0.73   0.87  ...       39.246214           0.609161
# 4       0.50    0.50   0.75   0.89  ...       39.246214           0.419686
# ...      ...     ...    ...    ...  ...             ...                ...
# 1645    0.48    0.48   0.74   0.86  ...       78.955890           0.307621
# 1646    0.48    0.48   0.74   0.86  ...       78.955890           0.532362
# 1647    0.49    0.48   0.74   0.86  ...       78.955890           0.570071
# 1648    0.49    0.48   0.74   0.86  ...       78.955890           0.531169
# 1649    0.49    0.48   0.73   0.86  ...       78.955890           0.559161
#
#       scaled_model_RMSD  scaled_query_RMSD  dG_separated    dSASA_int  \
# 0              0.056252           0.044806     19.708321  1472.935064
# 1              0.060631           0.044806     59.586646  1843.671070
# 2              0.030546           0.044806     56.250134  1609.165063
# 3              0.068129           0.044806     27.314403  1546.077081
# 4              0.032811           0.044806     20.159038  1206.538153
# ...                 ...                ...           ...          ...
# 1645           0.005123           0.011457    893.272378  1979.008027
# 1646           0.013022           0.011457    223.208736  1584.054934
# 1647           0.015135           0.011457   1050.032869  1595.052750
# 1648           0.012960           0.011457     19.805114  1530.011186
# 1649           0.014487           0.011457   2526.888272  1960.492635
#
#       nres_int  delta_unsatHbonds  packstat  dG_dSASA_norm
# 0         47.0               17.0  0.713741       0.013380
# 1         60.0               21.0  0.674735       0.032320
# 2         53.0               11.0  0.741571       0.034956
# 3         54.0               21.0  0.729679       0.017667
# 4         43.0                6.0  0.749578       0.016708
# ...        ...                ...       ...            ...
# 1645     103.0               15.0  0.550770       0.451374
# 1646      63.0               17.0  0.608707       0.140910
# 1647      64.0                7.0  0.610768       0.658306
# 1648      65.0                3.0  0.673359       0.012944
# 1649      78.0               25.0  0.559180       1.288905
#
# [1648 rows x 71 columns]

# %%
y_test
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1645    0
# 1646    0
# 1647    0
# 1648    0
# 1649    0
# Name: __target__DockQ, Length: 1648, dtype: int64

# %%
# interpret_model(final_model, X_new_sample=X_test,y_new_sample=y_test)

# %%
# lb = get_leaderboard()
