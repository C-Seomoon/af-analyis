# %%
import pandas as pd

# %%
df1=pd.read_csv('final_data_20250408.csv')
df2=pd.read_csv('rosetta_20250417.csv')

merged_df = pd.merge(df1, df2, on='model_path', how='left')

# %%
merged_df
# Out:
#                                                     pdb      query  seed  \
# 0     /home/cseomoon/project/ABAG/AbNb_benchmark/AF3...  8d9z_8d9z     1
# 1     /home/cseomoon/project/ABAG/AbNb_benchmark/AF3...  8d9z_8d9z     1
# 2     /home/cseomoon/project/ABAG/AbNb_benchmark/AF3...  8d9z_8d9z     1
# 3     /home/cseomoon/project/ABAG/AbNb_benchmark/AF3...  8d9z_8d9z     1
# 4     /home/cseomoon/project/ABAG/AbNb_benchmark/AF3...  8d9z_8d9z     1
# ...                                                 ...        ...   ...
# 3645  /home/cseomoon/project/ABAG/AbNb_benchmark/AF3...  8hp9_8hp9    10
# 3646  /home/cseomoon/project/ABAG/AbNb_benchmark/AF3...  8hp9_8hp9    10
# 3647  /home/cseomoon/project/ABAG/AbNb_benchmark/AF3...  8hp9_8hp9    10
# 3648  /home/cseomoon/project/ABAG/AbNb_benchmark/AF3...  8hp9_8hp9    10
# 3649  /home/cseomoon/project/ABAG/AbNb_benchmark/AF3...  8hp9_8hp9    10
#
#       sample                                          data_file  \
# ...

# %%
merged_df.to_csv('final_data_with_rosetta_250418.csv', index=False)

# %%
merged_df
# Out:
#                                                     pdb      query  seed  \
# 0     /home/cseomoon/project/ABAG/AbNb_benchmark/AF3...  8d9z_8d9z     1
# 1     /home/cseomoon/project/ABAG/AbNb_benchmark/AF3...  8d9z_8d9z     1
# 2     /home/cseomoon/project/ABAG/AbNb_benchmark/AF3...  8d9z_8d9z     1
# 3     /home/cseomoon/project/ABAG/AbNb_benchmark/AF3...  8d9z_8d9z     1
# 4     /home/cseomoon/project/ABAG/AbNb_benchmark/AF3...  8d9z_8d9z     1
# ...                                                 ...        ...   ...
# 3645  /home/cseomoon/project/ABAG/AbNb_benchmark/AF3...  8hp9_8hp9    10
# 3646  /home/cseomoon/project/ABAG/AbNb_benchmark/AF3...  8hp9_8hp9    10
# 3647  /home/cseomoon/project/ABAG/AbNb_benchmark/AF3...  8hp9_8hp9    10
# 3648  /home/cseomoon/project/ABAG/AbNb_benchmark/AF3...  8hp9_8hp9    10
# 3649  /home/cseomoon/project/ABAG/AbNb_benchmark/AF3...  8hp9_8hp9    10
#
#       sample                                          data_file  \
# ...

# %%
df=pd.read_csv('final_data_with_rosetta_20250418.csv')

# %%
pd.set_option('display.max_columns', None)  # 모든 컬럼 출력
pd.set_option('display.max_colwidth', None)  # 컬럼 값 잘리지 않게 설정

# %%
display(df[df.isnull().any(axis=1)])
# Out:
#                                                                                               pdb  \
# 1105   /home/cseomoon/project/ABAG/AbNb_benchmark/AF3_results/7t7b_7t7b/seed-2_sample-0/model.cif
# 2747  /home/cseomoon/project/ABAG/AbNb_benchmark/AF3_results/8e6j_8e6j/seed-10_sample-2/model.cif
# 3320   /home/cseomoon/project/ABAG/AbNb_benchmark/AF3_results/8cin_8cin/seed-5_sample-0/model.cif
#
#           query  seed  sample  \
# 1105  7t7b_7t7b     2       0
# 2747  8e6j_8e6j    10       2
# 3320  8cin_8cin     5       0
#
#                                                                                                data_file  \
# 1105   /home/cseomoon/project/ABAG/AbNb_benchmark/AF3_results/7t7b_7t7b/seed-2_sample-0/confidences.json
# 2747  /home/cseomoon/project/ABAG/AbNb_benchmark/AF3_results/8e6j_8e6j/seed-10_sample-2/confidences.json
# 3320   /home/cseomoon/project/ABAG/AbNb_benchmark/AF3_results/8cin_8cin/seed-5_sample-0/confidences.json
#
# ...
