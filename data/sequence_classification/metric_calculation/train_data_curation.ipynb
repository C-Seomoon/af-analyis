# %%
import af_analysis
import pandas as pd

# %%
df=pd.read_csv('negative_sorted_decoy_set_train.csv')
df
# Out:
#     antibody antigen  label neg_type
# 0       7q0i    7tl0      0     easy
# 1       7q0i    7upb      0     easy
# 2       7q0i    7vux      0     easy
# 3       7q0i    8oxw      0     easy
# 4       7q0i    7x6a      0     hard
# ..       ...     ...    ...      ...
# 360     8tbq    7uzc      0     easy
# 361     8tbq    8heb      0     easy
# 362     8tbq    7x6a      0     easy
# 363     8tbq    7unb      0     easy
# 364     8tbq    7r58      0     easy
#
# [365 rows x 4 columns]

# %%
# ── ① 맨 위쪽 import 구역 ───────────────────────────────────────────
import random          # ← 새로 추가
import argparse        # ← 새로 추가

# %%
from concurrent.futures import ProcessPoolExecutor, as_completed
import os, sys, time, multiprocessing
from datetime import datetime
import pandas as pd
import af_analysis

def process_pdb_id(antibody_id,antigen_id):
    """개별 PDB ID 처리 함수"""
    try:
        pair = f"{antibody_id}_{antigen_id}"
        print(f"Processing {pair}")
        base_dir = f"/home/cseomoon/project/ABAG/AbNb_benchmark/AF3_results/{pair}"
        if not os.path.exists(base_dir):
            return None, f"Directory not found for {pair}"
            
        my_data = af_analysis.data.Data(directory=base_dir)
        my_data.prep_dockq(verbose=False)
        # analysis.calculate_dockQ(my_data,
        #             rec_chains='A', lig_chains='H', 
        #             native_rec_chains='A', native_lig_chains='H', 
        #             verbose=False)
        
        analysis.pdockq(my_data, verbose=False)
        analysis.pdockq2(my_data, verbose=False)
        analysis.mpdockq(my_data, verbose=False)
        analysis.LIS_matrix(my_data, verbose=False)
        analysis.add_interface_metrics(my_data, verbose=False)
        my_data.analyze_chains()   
        my_data.add_chain_rmsd(align_chain='A', rmsd_chain='H')
        my_data.add_rmsd_scale() 
        return my_data, None
    except Exception as e:
        return None, f"Error processing {pair}: {e}"
        
if __name__ == "__main__":
    parser = argparse.ArgumentParser()
    parser.add_argument("--pilot", type=int, default=None,
                        help="테스트용으로 처리할 (무작위) 페어 개수")
    args = parser.parse_args()
    start_time = time.time()

    # 입력 파일 확인
    input_file = '/home/cseomoon/appl/af_analysis-0.1.4/data/sequence_classification/metric_calculation/negative_sorted_decoy_set_train.csv'
    if not os.path.exists(input_file):
        print(f"Input file not found: {input_file}")
        sys.exit(1)

    # 출력 디렉토리 준비
    output_dir = "/home/cseomoon/appl/af_analysis-0.1.4/data/sequence_classification/metric_calculation"
    os.makedirs(output_dir, exist_ok=True)
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    output_file = f"{output_dir}/chain_metrics_results_{timestamp}.csv"

    # negative_pairs 생성
    df = pd.read_csv(input_file)
    negative_pairs = [(row['antibody'], row['antigen']) for _, row in df.iterrows()]
    total_pairs = len(negative_pairs)


    # pilot 옵션이 있으면 무작위 샘플링
    if args.pilot is not None and 0 < args.pilot < total_pairs:
        random.seed(42)                       # 재현 가능하도록 고정(선택)
        negative_pairs = random.sample(negative_pairs, args.pilot)
        total_pairs = len(negative_pairs)
        print(f"[PILOT] {total_pairs} pairs만 선택해 실행합니다.")

    print(f"Found {total_pairs} pairs to process")
    print(f"Found {total_pairs} negative pairs to process")

    
   # 병렬 처리 설정
    num_workers = min(4, int(multiprocessing.cpu_count() * 0.75))
    print(f"Using {num_workers} workers for parallel processing")

    results = []
    errors = []
    completed = 0

    with ProcessPoolExecutor(max_workers=num_workers) as executor:
        # futures: { Future: (antibody, antigen) }
        futures = {
            executor.submit(process_pdb_id, ab, ag): (ab, ag)
            for ab, ag in negative_pairs
        }

        for future in as_completed(futures):
            ab, ag = futures[future]
            pair = f"{ab}_{ag}"
            result, error = future.result()

            completed += 1
            progress = (completed / total_pairs) * 100
            elapsed = time.time() - start_time
            eta = (elapsed / completed) * (total_pairs - completed) if completed else 0
            print(f"Progress: {progress:.1f}% ({completed}/{total_pairs}) - ETA: {eta:.1f}s")

            if result is not None:
                results.append(result)
                print(f"Completed {pair}")
            else:
                errors.append(error)
                print(error)

    # 결과 저장
    if results:
        merged = af_analysis.data.concat_data(results)
        merged.df.to_csv(output_file, index=False)
        print(f"Successfully processed {len(results)}/{total_pairs} folders")
        print(f"Results saved to {output_file}")
    else:
        print("No valid results to save")

    if errors:
        print(f"Encountered {len(errors)} errors:")
        for err in errors:
            print("  -", err)

    total_time = time.time() - start_time
    print(f"Total execution time: {total_time:.1f}s ({total_time/60:.1f}min)")
# Out:
# Found 365 negative pairs to process
# Using 4 workers for parallel processing
# Processing 7q0i_7upbProcessing 7q0i_7tl0Processing 7q0i_7vuxProcessing 7q0i_8oxw
#
#
#
# Processing 7q0i_7x6a
# Progress: 0.3% (1/365) - ETA: 74.2s
# Error processing 7q0i_7vux: name 'analysis' is not defined
# Processing 7q6c_7tl0
# Processing 7q6c_7uz7
# Processing 7q6c_7xdb
# Processing 7q6c_7wg3
# Processing 7q6c_7u2d
# Processing 7qnw_7t7b
# Processing 7qnw_8dg9
# Progress: 0.5% (2/365) - ETA: 42.6s
# Error processing 7q0i_7upb: name 'analysis' is not defined
# Progress: 0.8% (3/365) - ETA: 29.9s
# Error processing 7q0i_7tl0: name 'analysis' is not defined
# Progress: 1.1% (4/365) - ETA: 23.3s
# Error processing 7q0i_8oxw: name 'analysis' is not defined
# Progress: 1.4% (5/365) - ETA: 23.0s
# Error processing 7q6c_7tl0: name 'analysis' is not defined
# Progress: 1.6% (6/365) - ETA: 21.5s
# Error processing 7q0i_7x6a: name 'analysis' is not defined
# Progress: 1.9% (7/365) - ETA: 19.9s
# Error processing 7q6c_7wg3: name 'analysis' is not defined
# Progress: 2.2% (8/365) - ETA: 17.9s
# Error processing 7q6c_7uz7: name 'analysis' is not defined
# Processing 7qnw_8ath
# Processing 7qnw_8fgx
# Progress: 2.5% (9/365) - ETA: 16.1s
# Error processing 7q6c_7xdb: name 'analysis' is not defined
# Progress: 2.7% (10/365) - ETA: 15.0s
# Error processing 7q6c_7u2d: name 'analysis' is not defined
# Processing 7qnw_8il3
# Processing 7r58_7xcz
# Processing 7r58_8oxwProcessing 7r58_7t17
#
# Processing 7r58_8gzz
# Processing 7r58_7tp4
# Processing 7so5_8c3v
# Processing 7so5_8f6l
# Processing 7so5_7r58
# Progress: 3.0% (11/365) - ETA: 14.6s
# Error processing 7qnw_7t7b: name 'analysis' is not defined
# Progress: 3.3% (12/365) - ETA: 13.7s
# Error processing 7qnw_8ath: name 'analysis' is not defined
# Progress: 3.6% (13/365) - ETA: 13.3s
# Error processing 7qnw_8fgx: name 'analysis' is not defined
# Progress: 3.8% (14/365) - ETA: 12.3s
# Error processing 7qnw_8dg9: name 'analysis' is not defined
# Progress: 4.1% (15/365) - ETA: 12.2s
# Error processing 7qnw_8il3: name 'analysis' is not defined
# Progress: 4.4% (16/365) - ETA: 11.6s
# Error processing 7r58_7xcz: name 'analysis' is not defined
# Progress: 4.7% (17/365) - ETA: 11.8s
# Error processing 7r58_7t17: name 'analysis' is not defined
# Progress: 4.9% (18/365) - ETA: 11.3s
# Error processing 7r58_8gzz: name 'analysis' is not defined
# Progress: 5.2% (19/365) - ETA: 11.0s
# Error processing 7r58_7tp4: name 'analysis' is not defined
# Processing 7so5_8ath
# Processing 7so5_7tl0Processing 7sww_7uvh
#
# Progress: 5.5% (20/365) - ETA: 10.5s
# Error processing 7r58_8oxw: name 'analysis' is not defined
# Progress: 5.8% (21/365) - ETA: 10.6s
# Error processing 7so5_8c3v: name 'analysis' is not defined
# Progress: 6.0% (22/365) - ETA: 10.1s
# Error processing 7so5_8f6l: name 'analysis' is not defined
# Processing 7sww_8fgx
# Processing 7sww_7zlk
# Processing 7sww_7upb
# Processing 7sww_7x6a
# Processing 7t01_7xcz
# Processing 7t01_8tbq
# Processing 7t01_8f6l
# Processing 7t01_8e6j
# Progress: 6.3% (23/365) - ETA: 9.9s
# Error processing 7so5_7r58: name 'analysis' is not defined
# Progress: 6.6% (24/365) - ETA: 9.5s
# Error processing 7so5_8ath: name 'analysis' is not defined
# Progress: 6.8% (25/365) - ETA: 9.6s
# Error processing 7sww_7uvh: name 'analysis' is not defined
# Progress: 7.1% (26/365) - ETA: 9.5s
# Error processing 7so5_7tl0: name 'analysis' is not defined
# Progress: 7.4% (27/365) - ETA: 9.3s
# Error processing 7sww_8fgx: name 'analysis' is not defined
# Progress: 7.7% (28/365) - ETA: 9.2s
# Error processing 7sww_7zlk: name 'analysis' is not defined
# Progress: 7.9% (29/365) - ETA: 9.2s
# Error processing 7sww_7upb: name 'analysis' is not defined
# Progress: 8.2% (30/365) - ETA: 9.0s
# Error processing 7t01_7xcz: name 'analysis' is not defined
# Processing 7t01_8g4p
# Processing 7t17_7uzc
# Progress: 8.5% (31/365) - ETA: 8.9s
# Error processing 7t01_8tbq: name 'analysis' is not defined
# Progress: 8.8% (32/365) - ETA: 8.9s
# Error processing 7t01_8f6l: name 'analysis' is not defined
# Processing 7t17_7tp3
# Processing 7t17_7uz7
# Processing 7t17_8c3v
# Processing 7t17_7vux
# Processing 7t7b_7upk
# Processing 7t7b_7q6c
# Processing 7t7b_8ath
# Processing 7t7b_8f6o
# Progress: 9.0% (33/365) - ETA: 8.8s
# Error processing 7t01_8g4p: name 'analysis' is not defined
# Progress: 9.3% (34/365) - ETA: 8.6s
# Error processing 7t01_8e6j: name 'analysis' is not defined
# Progress: 9.6% (35/365) - ETA: 8.5s
# Error processing 7sww_7x6a: name 'analysis' is not defined
# Progress: 9.9% (36/365) - ETA: 8.4s
# Error processing 7t17_7uzc: name 'analysis' is not defined
# Progress: 10.1% (37/365) - ETA: 8.3s
# Error processing 7t17_7tp3: name 'analysis' is not defined
# Progress: 10.4% (38/365) - ETA: 8.3s
# Error processing 7t17_8c3v: name 'analysis' is not defined
# Progress: 10.7% (39/365) - ETA: 8.2s
# Error processing 7t17_7vux: name 'analysis' is not defined
# Progress: 11.0% (40/365) - ETA: 8.3s
# Error processing 7t7b_7q6c: name 'analysis' is not defined
# Processing 7t7b_7x6a
# Processing 7tl0_7uz7Processing 7tl0_7wpe
#
# Processing 7tl0_7yru
# Progress: 11.2% (41/365) - ETA: 8.1s
# Error processing 7t7b_7upk: name 'analysis' is not defined
# Progress: 11.5% (42/365) - ETA: 8.0s
# Error processing 7t17_7uz7: name 'analysis' is not defined
# Progress: 11.8% (43/365) - ETA: 7.8s
# Error processing 7t7b_8ath: name 'analysis' is not defined
# Progress: 12.1% (44/365) - ETA: 7.8s
# Error processing 7t7b_8f6o: name 'analysis' is not defined
# Processing 7tl0_7u2d
# Processing 7tl0_8ez3
# Processing 7tp3_7uvhProcessing 7tp3_8cz5
#
# Processing 7tp3_8ds5
# Progress: 12.3% (45/365) - ETA: 8.0s
# Error processing 7tl0_7yru: name 'analysis' is not defined
# Progress: 12.6% (46/365) - ETA: 8.2s
# Error processing 7t7b_7x6a: name 'analysis' is not defined
# Progress: 12.9% (47/365) - ETA: 8.0s
# Error processing 7tl0_7u2d: name 'analysis' is not defined
# Progress: 13.2% (48/365) - ETA: 7.8s
# Error processing 7tl0_7wpe: name 'analysis' is not defined
# Progress: 13.4% (49/365) - ETA: 7.7s
# Error processing 7tl0_7uz7: name 'analysis' is not defined
# Processing 7tp3_7r58
# Processing 7tp3_8dad
# Processing 7tp4_7t7bProcessing 7tp4_7u5b
#
# Processing 7tp4_8g3p
# Processing 7tp4_7vuxProcessing 7tp4_8dg9
#
# Progress: 13.7% (50/365) - ETA: 7.9s
# Error processing 7tp3_7uvh: name 'analysis' is not defined
# Progress: 14.0% (51/365) - ETA: 7.7s
# Error processing 7tp3_8ds5: name 'analysis' is not defined
# Progress: 14.2% (52/365) - ETA: 7.6s
# Error processing 7tl0_8ez3: name 'analysis' is not defined
# Progress: 14.5% (53/365) - ETA: 7.4s
# Error processing 7tp3_8cz5: name 'analysis' is not defined
# Progress: 14.8% (54/365) - ETA: 7.5s
# Error processing 7tp3_7r58: name 'analysis' is not defined
# Progress: 15.1% (55/365) - ETA: 7.4s
# Error processing 7tp4_7u5b: name 'analysis' is not defined
# Progress: 15.3% (56/365) - ETA: 7.3s
# Error processing 7tp3_8dad: name 'analysis' is not defined
# Processing 7u2d_8oxw
# Processing 7u2d_8j7t
# Processing 7u2d_8d9z
# Processing 7u2d_7so5
# Processing 7u2d_8gb6
# Processing 7u5b_7uzc
# Processing 7u5b_8f6oProgress: 15.6% (57/365) - ETA: 7.2s
# Error processing 7tp4_7t7b: name 'analysis' is not defined
# Progress: 15.9% (58/365) - ETA: 7.3s
# Error processing 7tp4_7vux: name 'analysis' is not defined
# Progress: 16.2% (59/365) - ETA: 7.2s
# Error processing 7tp4_8g3p: name 'analysis' is not defined
# Progress: 16.4% (60/365) - ETA: 7.1s
# Error processing 7tp4_8dg9: name 'analysis' is not defined
# Progress: 16.7% (61/365) - ETA: 7.2s
# Error processing 7u2d_8oxw: name 'analysis' is not defined
# Progress: 17.0% (62/365) - ETA: 7.1s
# Error processing 7u2d_8d9z: name 'analysis' is not defined
# Progress: 17.3% (63/365) - ETA: 6.9s
# Error processing 7u2d_8j7t: name 'analysis' is not defined
#
# Processing 7u5b_7tp4Processing 7u5b_7vux
#
# Processing 7u5b_7unbProcessing 7unb_8dxt
#
# Progress: 17.5% (64/365) - ETA: 7.1s
# Error processing 7u2d_8gb6: name 'analysis' is not defined
# Progress: 17.8% (65/365) - ETA: 6.9s
# Error processing 7u5b_8f6o: name 'analysis' is not defined
# Progress: 18.1% (66/365) - ETA: 6.8s
# Error processing 7u2d_7so5: name 'analysis' is not defined
# Progress: 18.4% (67/365) - ETA: 6.7s
# Error processing 7u5b_7uzc: name 'analysis' is not defined
# Processing 7unb_7u5b
# Processing 7unb_7wg3
# Processing 7unb_7u2d
# Processing 7unb_7zwi
# Processing 7upb_7vux
# Processing 7upb_8hc4Processing 7upb_7upk
#
# Processing 7upb_8heb
# Processing 7upb_7uvf
# Progress: 18.6% (68/365) - ETA: 6.8s
# Error processing 7u5b_7vux: name 'analysis' is not defined
# Progress: 18.9% (69/365) - ETA: 6.7s
# Error processing 7u5b_7tp4: name 'analysis' is not defined
# Progress: 19.2% (70/365) - ETA: 6.6s
# Error processing 7u5b_7unb: name 'analysis' is not defined
# Progress: 19.5% (71/365) - ETA: 6.5s
# Error processing 7unb_8dxt: name 'analysis' is not defined
# Progress: 19.7% (72/365) - ETA: 6.6s
# Error processing 7unb_7u5b: name 'analysis' is not defined
# Progress: 20.0% (73/365) - ETA: 6.5s
# Error processing 7unb_7zwi: name 'analysis' is not defined
# Progress: 20.3% (74/365) - ETA: 6.4s
# Error processing 7unb_7wg3: name 'analysis' is not defined
# Progress: 20.5% (75/365) - ETA: 6.3s
# Error processing 7unb_7u2d: name 'analysis' is not defined
# Progress: 20.8% (76/365) - ETA: 6.4s
# Error processing 7upb_7vux: name 'analysis' is not defined
# Processing 7upk_8f6o
# Processing 7upk_8dad
# Progress: 21.1% (77/365) - ETA: 6.4s
# Error processing 7upb_7upk: name 'analysis' is not defined
# Progress: 21.4% (78/365) - ETA: 6.3s
# Error processing 7upb_7uvf: name 'analysis' is not defined
# Processing 7upk_7x8p
# Processing 7upk_7tp4
# Processing 7upk_7upbProcessing 7uvf_7sww
#
# Processing 7uvf_7t7b
# Processing 7uvf_7so5
# Processing 7uvf_8r1d
# Processing 7uvf_8ds5
# Processing 7uvh_8ath
# Progress: 21.6% (79/365) - ETA: 6.4s
# Error processing 7upk_8f6o: name 'analysis' is not defined
# Progress: 21.9% (80/365) - ETA: 6.3s
# Error processing 7upb_8heb: name 'analysis' is not defined
# Progress: 22.2% (81/365) - ETA: 6.3s
# Error processing 7upb_8hc4: name 'analysis' is not defined
# Progress: 22.5% (82/365) - ETA: 6.2s
# Error processing 7upk_8dad: name 'analysis' is not defined
# Progress: 22.7% (83/365) - ETA: 6.2s
# Error processing 7upk_7x8p: name 'analysis' is not defined
# Progress: 23.0% (84/365) - ETA: 6.2s
# Error processing 7upk_7tp4: name 'analysis' is not defined
# Progress: 23.3% (85/365) - ETA: 6.1s
# Error processing 7uvf_7sww: name 'analysis' is not defined
# Progress: 23.6% (86/365) - ETA: 6.1s
# Error processing 7upk_7upb: name 'analysis' is not defined
# Progress: 23.8% (87/365) - ETA: 6.0s
# Error processing 7uvf_7t7b: name 'analysis' is not defined
# Processing 7uvh_8r1d
# Processing 7uvh_7xdb
# Processing 7uvh_7u5b
# Progress: 24.1% (88/365) - ETA: 6.1s
# Error processing 7uvf_8ds5: name 'analysis' is not defined
# Progress: 24.4% (89/365) - ETA: 6.0s
# Error processing 7uvf_7so5: name 'analysis' is not defined
# Progress: 24.7% (90/365) - ETA: 6.0s
# Error processing 7uvh_8ath: name 'analysis' is not defined
# Processing 7uz7_7q6cProcessing 7uvh_8dxt
#
# Processing 7uz7_8dg9
# Processing 7uz7_8f6l
# Processing 7uz7_8sgn
# Processing 7uz7_8hp9
# Processing 7uzc_7xczProcessing 7uzc_7xy8Processing 7uzc_7yruProcessing 7uzc_7t17
#
#
#
# Progress: 24.9% (91/365) - ETA: 6.1s
# Error processing 7uvh_7u5b: name 'analysis' is not defined
# Progress: 25.2% (92/365) - ETA: 6.0s
# Error processing 7uvf_8r1d: name 'analysis' is not defined
# Progress: 25.5% (93/365) - ETA: 6.1s
# Error processing 7uz7_7q6c: name 'analysis' is not defined
# Progress: 25.8% (94/365) - ETA: 6.0s
# Error processing 7uvh_8dxt: name 'analysis' is not defined
# Progress: 26.0% (95/365) - ETA: 5.9s
# Error processing 7uvh_8r1d: name 'analysis' is not defined
# Progress: 26.3% (96/365) - ETA: 5.8s
# Error processing 7uvh_7xdb: name 'analysis' is not defined
# Processing 7uzc_8e6j
# Processing 7vux_7zwiProcessing 7vux_8e6j
#
# Processing 7vux_8dg9
# Processing 7vux_7wbh
# Processing 7vux_7so5Processing 7wbh_8f6l
#
# Processing 7wbh_8ez3
# Processing 7wbh_8heb
# Processing 7wbh_8dg9
# Processing 7wbh_8tbq
# Processing 7wcp_7wbh
# Processing 7wcp_8il3
# Processing 7wcp_8f6l
# Processing 7wcp_7yru
# Processing 7wcp_8dg9
# Processing 7wg3_8sgn
# Processing 7wg3_7uvh
# Processing 7wg3_8c3v
# Processing 7wg3_8gb6
# Processing 7wg3_7upb
# Processing 7wog_7x8p
# Processing 7wog_8ez3
# Processing 7wog_7zlk
# Processing 7wog_8gzz
# Processing 7wog_8dg9
# Processing 7wpe_8j7t
# Processing 7wpe_8dg9
# Processing 7wpe_7x8p
# Processing 7wpe_7vux
# Processing 7wpe_7wbh
# Processing 7wrl_7r58
# Processing 7wrl_8dxu
# Processing 7wrl_8g3p
# Processing 7wrl_7uvh
# Processing 7wrl_7yds
# Processing 7wro_8j7t
# Processing 7wro_7unbProcessing 7wro_7upb
# Processing 7wro_7zlk
#
# Processing 7wro_7uzc
# Processing 7wsc_7u2d
# Processing 7wsc_8il3Processing 7wsc_7tl0
#
# Processing 7wsc_8j7t
# Processing 7wsc_7u5b
# Processing 7x6a_8e6j
# Processing 7x6a_7yds
# Processing 7x6a_8d9z
# Processing 7x6a_7q6c
# Processing 7x6a_8dxtProcessing 7x7t_7unb
#
# Processing 7x7t_8g3p
# Processing 7x7t_7t7b
# Processing 7x7t_8ez3
# Processing 7x7t_7yru
# Processing 7x8p_8sgn
# Processing 7x8p_7wbh
# Processing 7x8p_7yds
# Processing 7x8p_8cz5
# Processing 7x8p_8f6oProcessing 7xcz_8sgn
#
# Processing 7xcz_7t7bProcessing 7xcz_7z2m
#
# Processing 7xcz_7x8p
# Processing 7xcz_8d9z
# Processing 7xdb_7zwi
# Processing 7xdb_7q6c
# Processing 7xdb_8g4p
# Processing 7xdb_7u5b
# Processing 7xdb_7x6a
# Processing 7xy8_7upbProcessing 7xy8_8hp9
#
# Processing 7xy8_7x6a
# Processing 7xy8_7u2d
# Processing 7xy8_7wcp
# Processing 7yds_8hc4
# Processing 7yds_8dxuProcessing 7yds_7upb
#
# Processing 7yds_7uzc
# Processing 7yds_8cin
# Processing 7yru_8f6o
# Processing 7yru_7x8pProcessing 7yru_8e6j
#
# Processing 7yru_7vux
# Processing 7yru_7uvf
# Processing 7z2m_7tl0
# Processing 7z2m_7upb
# Processing 7z2m_8dg9
# Processing 7z2m_7uvf
# Processing 7z2m_8c3v
# Processing 7zlk_8ds5Processing 7zlk_7so5
#
# Processing 7zlk_7tl0
# Processing 7zlk_7x8pProcessing 7zlk_8dad
#
# Processing 7zwi_8j7tProcessing 7zwi_7zlk
#
# Processing 7zwi_7unb
# Processing 7zwi_8sgn
# Processing 7zwi_7so5
# Processing 8ath_8gzz
# Processing 8ath_8hc4
# Processing 8ath_7uz7
# Processing 8ath_8oxw
# Processing 8ath_7q6c
# Processing 8c3v_8f6o
# Processing 8c3v_8j7t
# Processing 8c3v_8hp9
# Processing 8c3v_7zwi
# Processing 8c3v_7unb
# Processing 8cii_7zwi
# Processing 8cii_7q6c
# Processing 8cii_8ath
# Processing 8cii_7xy8
# Processing 8cii_7x6a
# Processing 8cin_7wg3
# Processing 8cin_7u5b
# Processing 8cin_8f6o
# Processing 8cin_8tbqProcessing 8cin_8r1d
#
# Processing 8cz5_8hpv
# Processing 8cz5_8f6o
# Processing 8cz5_8hc4
# Processing 8cz5_7vux
# Processing 8cz5_8gzz
# Processing 8d9z_7uzcProcessing 8d9z_8dg9
#
# Processing 8d9z_8ath
# Processing 8d9z_8cz5
# Processing 8d9z_7xdb
# Processing 8dad_8gb6
# Processing 8dad_8ath
# Processing 8dad_7wg3
# Processing 8dad_8cz5
# Processing 8dad_8f6l
# Processing 8dg9_7q0i
# Processing 8dg9_7uz7
# Processing 8dg9_7so5
# Processing 8dg9_7qnw
# Processing 8dg9_7z2m
# Processing 8ds5_7upk
# Processing 8ds5_8f6o
# Processing 8ds5_7uvh
# Processing 8ds5_7tp3
# Processing 8ds5_7xdb
# Processing 8dxt_8g3p
# Processing 8dxt_8ath
# Processing 8dxt_8tbq
# Processing 8dxt_7upb
# Processing 8dxt_7t01
# Processing 8dxu_7r58
# Processing 8dxu_7yds
# Processing 8dxu_7tp3
# Processing 8dxu_7zwi
# Processing 8dxu_8ds5
# Processing 8e6j_7tl0
# Processing 8e6j_7uvfProcessing 8e6j_7upb
#
# Processing 8e6j_8f6o
# Processing 8e6j_8ath
# Processing 8ez3_7wg3
# Processing 8ez3_7t01
# Processing 8ez3_8g4p
# Processing 8ez3_8cz5
# Processing 8ez3_8g3pProcessing 8f6l_8f6o
#
# Processing 8f6l_8fgx
# Processing 8f6l_8dg9
# Processing 8f6l_7xdb
# Processing 8f6l_8ds5
# Processing 8f6o_7tl0
# Processing 8f6o_7sww
# Processing 8f6o_8heb
# Processing 8f6o_8gzz
# Processing 8f6o_8f6lProcessing 8fgx_7uvf
#
# Processing 8fgx_7z2m
# Processing 8fgx_7so5
# Processing 8fgx_8ds5
# Processing 8fgx_7unb
# Processing 8g3p_7q0i
# Processing 8g3p_7t7b
# Processing 8g3p_7t17
# Processing 8g3p_7wcpProcessing 8g3p_8ez3
#
# Processing 8g4p_7z2m
# Processing 8g4p_7uvh
# Processing 8g4p_8il3
# Processing 8g4p_7upb
# Processing 8g4p_8g3p
# Processing 8gb6_7vux
# Processing 8gb6_8j7t
# Processing 8gb6_8fgx
# Processing 8gb6_8f6l
# Processing 8gb6_8dad
# Processing 8gzz_8ez3
# Processing 8gzz_7r58
# Processing 8gzz_7x6a
# Processing 8gzz_7t17
# Processing 8gzz_8oxw
# Processing 8hc4_7xy8
# Processing 8hc4_7wg3Processing 8hc4_7x8p
#
# Processing 8hc4_7upk
# Processing 8hc4_7uz7
# Processing 8heb_7u5b
# Processing 8heb_8ds5
# Processing 8heb_8ez3
# Processing 8heb_7upbProcessing 8heb_8hpv
#
# Processing 8hp9_8c3v
# Processing 8hp9_8ez3
# Processing 8hp9_7uvf
# Processing 8hp9_8ath
# Processing 8hp9_7x8p
# Processing 8hpv_8dg9
# Processing 8hpv_7so5
# Processing 8hpv_7unb
# Processing 8hpv_7uvf
# Processing 8hpv_7wbh
# Processing 8il3_8dadProcessing 8il3_8sgn
#
# Processing 8il3_8f6l
# Processing 8il3_8oxw
# Processing 8il3_7wog
# Processing 8j7t_8oxw
# Processing 8j7t_8dg9Processing 8j7t_7wpe
#
# Processing 8j7t_7vux
# Processing 8j7t_7tp3
# Processing 8oxw_8dad
# Processing 8oxw_8hp9
# Processing 8oxw_7zlk
# Processing 8oxw_7uz7
# Processing 8oxw_7wcp
# Processing 8qrg_8g3p
# Processing 8qrg_8sgn
# Processing 8qrg_7x8p
# Processing 8qrg_8f6o
# Processing 8qrg_8gzz
# Processing 8r1d_8cin
# Processing 8r1d_7x8p
# Processing 8r1d_7z2m
# Processing 8r1d_7zlk
# Processing 8r1d_8oxwProcessing 8sdg_7yds
#
# Processing 8sdg_8ds5
# Processing 8sdg_7z2m
# Processing 8sdg_8il3
# Processing 8sdg_7tp3
# Processing 8sgn_7u5b
# Processing 8sgn_7tp3
# Processing 8sgn_8d9z
# Processing 8sgn_7upk
# Processing 8sgn_8cz5
# Processing 8tbq_7uzc
# Processing 8tbq_8heb
# Processing 8tbq_7x6a
# Processing 8tbq_7unb
# Processing 8tbq_7r58
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 72
#      65 with ProcessPoolExecutor(max_workers=num_workers) as executor:
#      66     # futures: { Future: (antibody, antigen) }
#      67     futures = {
#      68         executor.submit(process_pdb_id, ab, ag): (ab, ag)
#      69         for ab, ag in negative_pairs
#      70     }
# ---> 72     for future in as_completed(futures):
#      73         ab, ag = futures[future]
#      74         pair = f"{ab}_{ag}"
#
# File ~/miniconda3/envs/Abnb/lib/python3.10/concurrent/futures/_base.py:245, in as_completed(fs, timeout)
#     240     if wait_timeout < 0:
#     241         raise TimeoutError(
#     242                 '%d (of %d) futures unfinished' % (
#     243                 len(pending), total_futures))
# --> 245 waiter.event.wait(wait_timeout)
#     247 with waiter.lock:
#     248     finished = waiter.finished_futures
#
# File ~/miniconda3/envs/Abnb/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File ~/miniconda3/envs/Abnb/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:
