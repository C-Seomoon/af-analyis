# %%
import pandas as pd
from pathlib import Path
import os

# 1) 파일 경로 설정
CSV_PATH       = "negative_sorted_decoy_set_test.csv"  # CSV 파일 경로
ANTIBODY_DIR   = Path("/home/cseomoon/project/ABAG/2025_H_L_A/Antibody")
ANTIGEN_DIR    = Path("/home/cseomoon/project/ABAG/2025_H_L_A/Antigen")
OUTPUT_DIR     = Path("/home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta")         # 출력 폴더
OUTPUT_DIR.mkdir(exist_ok=True)

# 2) CSV 읽기
df = pd.read_csv(CSV_PATH, usecols=["antibody", "antigen"])

# 3) 각 행 순회하며 complex FASTA 생성
for _, row in df.iterrows():
    ab_id = row["antibody"]
    ag_id = row["antigen"]

    # Antibody FASTA 파일 경로 (예: 6x97_H_L.fasta)
    ab_file = ANTIBODY_DIR / f"{ab_id}_H_L.fasta"
    # Antigen FASTA 파일 경로 (예: 6x97_A.fasta)
    ag_file = ANTIGEN_DIR  / f"{ag_id}_A.fasta"

    # 존재 확인
    if not ab_file.exists():
        print(f"[Warning] Antibody file not found: {ab_file}")
        continue
    if not ag_file.exists():
        print(f"[Warning] Antigen file not found:  {ag_file}")
        continue

    # 출력 파일명: {antibody}_{antigen}.fasta
    out_file = OUTPUT_DIR / f"{ab_id}_{ag_id}.fasta"

    # 4) 두 FASTA 이어붙여 저장
    with open(out_file, "w") as fout:
        # antibody 내용
        with open(ab_file) as fab:
            fout.write(fab.read().rstrip() + "\n")
        # antigen 내용
        with open(ag_file) as fag:
            fout.write(fag.read().rstrip() + "\n")

    print(f"Created complex FASTA: {out_file}")
# Out:
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/6x97_7sgm.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/6x97_7su0.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/6x97_7tfo.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/6x97_7zr7.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/6x97_7o9w.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7ew5_7wrv.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7ew5_7yqx.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7ew5_7su0.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7ew5_7zr7.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7ew5_7sbg.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7kf0_7sjo.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7kf0_7kf1.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7kf0_7sjn.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7kf0_7su0.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7kf0_7wo5.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7kf1_7kf0.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7kf1_7soc.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7kf1_7o9w.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7kf1_7r40.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7kf1_7wo5.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7np1_7shy.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7np1_7z4t.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7np1_7o9w.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7np1_7zr7.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7np1_7sjn.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7nx3_7z2m.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7nx3_7kf1.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7nx3_7o9w.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7nx3_7su1.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7nx3_7yqz.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7o9w_7vng.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7o9w_7nx3.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7o9w_7tfo.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7o9w_7zf9.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7o9w_7yqx.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7r40_7su1.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7r40_7tfo.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7r40_7ew5.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7r40_6x97.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7r40_7zf9.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7s0e_7wrv.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7s0e_7kf0.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7s0e_7tee.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7s0e_7sjn.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7s0e_7ew5.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7sbg_7tee.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7sbg_7wo5.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7sbg_7kf1.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7sbg_7wrv.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7sbg_7su1.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7sgm_7zr7.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7sgm_7wrv.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7sgm_7kf1.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7sgm_7ew5.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7sgm_7zf9.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7shy_7ued.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7shy_7sgm.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7shy_7kf0.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7shy_7yqz.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7shy_6x97.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7sjn_6x97.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7sjn_7sbg.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7sjn_7soc.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7sjn_7sjo.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7sjn_7zf9.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7sjo_7z4t.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7sjo_7su0.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7sjo_7yqz.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7sjo_7sgm.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7sjo_7sjn.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7soc_7sgm.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7soc_7ew5.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7soc_7yqz.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7soc_7ued.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7soc_7vng.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7su0_7wo5.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7su0_7zf9.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7su0_7ew5.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7su0_7soc.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7su0_7su1.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7su1_7ew5.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7su1_7t25.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7su1_7sgm.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7su1_7su0.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7su1_7soc.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7swn_7soc.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7swn_7nx3.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7swn_7sjo.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7swn_7sjn.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7swn_7su0.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7t25_7yqx.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7t25_7zr7.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7t25_7kf1.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7t25_7r40.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7t25_7su1.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7tee_7nx3.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7tee_7sbg.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7tee_7z2m.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7tee_7yqz.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7tee_7sgm.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7tfo_7ued.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7tfo_6x97.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7tfo_7ew5.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7tfo_7z4t.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7tfo_7wo5.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7ued_7sjn.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7ued_7kf1.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7ued_7o9w.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7ued_7su0.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7ued_7sbg.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7vng_7zf9.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7vng_7su1.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7vng_7sjn.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7vng_7sbg.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7vng_7zr7.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7vyr_7tee.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7vyr_7su1.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7vyr_7yqz.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7vyr_7tfo.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7vyr_7sgm.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7wo5_7tee.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7wo5_7sgm.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7wo5_7kf1.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7wo5_7shy.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7wo5_7zf9.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7wrv_7o9w.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7wrv_7shy.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7wrv_7su1.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7wrv_7sjn.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7wrv_7yqz.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7x7o_7kf0.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7x7o_7t25.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7x7o_7su0.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7x7o_7sjo.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7x7o_7wo5.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7yqx_7wo5.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7yqx_7nx3.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7yqx_7z4t.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7yqx_7kf1.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7yqx_7shy.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7yqz_7soc.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7yqz_7o9w.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7yqz_7ued.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7yqz_7shy.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7yqz_7tfo.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7z2m_7wo5.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7z2m_7wrv.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7z2m_7r40.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7z2m_7kf1.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7z2m_7tfo.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7z4t_7zf9.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7z4t_7sbg.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7z4t_7wrv.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7z4t_7shy.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7z4t_7wo5.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7zf9_7sjo.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7zf9_7su0.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7zf9_7yqz.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7zf9_7sjn.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7zf9_7t25.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7zr7_6x97.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7zr7_7sbg.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7zr7_7nx3.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7zr7_7ued.fasta
# Created complex FASTA: /home/cseomoon/project/ABAG/2025_H_L_A/20250504_seeds_10/negative/fasta/7zr7_7zf9.fasta
